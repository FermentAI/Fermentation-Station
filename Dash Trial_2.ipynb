# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas_datareader.data as web
import datetime

# %%
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-873aa293d964> in <module>
# ----> 1 print(df.head())
#
# NameError: name 'df' is not defined

# %%
app = dash.Dash()

# %%
app.layout = html.Div(children=[
    html.Div(children='''
        symbol to graph: 
    '''),
    
    dcc.Input(id='input',value='', type='text'),
    html.Div(id='output-graph')
])

@app.callback(
    Output(component_id='output-graph',component_property='children'),
    [Input(component_id='input', component_property='value')]
    )
def update_graph(input_data):
    
    start = datetime.datetime(2015, 1, 1)
    end = datetime.datetime.now()
    df = web.DataReader(input_data, 'yahoo', start, end)
    
    return dcc.Graph(
        id = 'example-graph',
        figure={
            'data': [
                {'x': df.index, 'y':df.Close, 'type': 'line', 'name': input_data},
            ],
            'layout': {
                'title': input_data
                }
            }
    )

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [25/Feb/2021 19:47:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2021 19:47:57] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2021 19:47:57] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 153, in _read_one_data
#     resp = self._get_response(url, params=params)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 181, in _get_response
#     raise RemoteDataError(msg)
# pandas_datareader._utils.RemoteDataError: Unable to read URL: https://finance.yahoo.com/quote//history?period1=1420113600&period2=1614340799&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420113600%26period2%3d1614340799%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420113600%26period2%3d1614340799%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# 127.0.0.1 - - [25/Feb/2021 19:48:00] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 165, in _read_one_data
#     prices["Date"] = to_datetime(to_datetime(prices["Date"], unit="s").dt.date)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Date'
# 127.0.0.1 - - [25/Feb/2021 19:48:01] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Feb/2021 19:48:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2021 19:48:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2021 19:48:01] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 165, in _read_one_data
#     prices["Date"] = to_datetime(to_datetime(prices["Date"], unit="s").dt.date)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Date'
# 127.0.0.1 - - [25/Feb/2021 19:48:10] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Feb/2021 19:48:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2021 19:48:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2021 19:48:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2021 19:48:11] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 165, in _read_one_data
#     prices["Date"] = to_datetime(to_datetime(prices["Date"], unit="s").dt.date)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Date'
# 127.0.0.1 - - [25/Feb/2021 19:48:11] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Feb/2021 19:48:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2021 19:48:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2021 19:48:13] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 153, in _read_one_data
#     resp = self._get_response(url, params=params)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 181, in _get_response
#     raise RemoteDataError(msg)
# pandas_datareader._utils.RemoteDataError: Unable to read URL: https://finance.yahoo.com/quote//history?period1=1420113600&period2=1614340799&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420113600%26period2%3d1614340799%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420113600%26period2%3d1614340799%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# 127.0.0.1 - - [25/Feb/2021 19:48:13] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Feb/2021 19:48:32] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol ya using YahooDailyReader
# 127.0.0.1 - - [25/Feb/2021 19:48:32] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol yah using YahooDailyReader
# 127.0.0.1 - - [25/Feb/2021 19:48:32] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol yaho using YahooDailyReader
# 127.0.0.1 - - [25/Feb/2021 19:48:32] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol yahoo using YahooDailyReader
# 127.0.0.1 - - [25/Feb/2021 19:48:32] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol yaho using YahooDailyReader
# 127.0.0.1 - - [25/Feb/2021 19:48:33] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol yah using YahooDailyReader
# 127.0.0.1 - - [25/Feb/2021 19:48:34] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol ya using YahooDailyReader
# 127.0.0.1 - - [25/Feb/2021 19:48:34] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Feb/2021 19:48:35] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 153, in _read_one_data
#     resp = self._get_response(url, params=params)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 181, in _get_response
#     raise RemoteDataError(msg)
# pandas_datareader._utils.RemoteDataError: Unable to read URL: https://finance.yahoo.com/quote//history?period1=1420113600&period2=1614340799&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420113600%26period2%3d1614340799%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420113600%26period2%3d1614340799%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# 127.0.0.1 - - [25/Feb/2021 19:48:36] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 165, in _read_one_data
#     prices["Date"] = to_datetime(to_datetime(prices["Date"], unit="s").dt.date)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Date'
# 127.0.0.1 - - [25/Feb/2021 19:48:44] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 165, in _read_one_data
#     prices["Date"] = to_datetime(to_datetime(prices["Date"], unit="s").dt.date)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Date'
# 127.0.0.1 - - [25/Feb/2021 19:48:44] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
# ...
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 165, in _read_one_data
#     prices["Date"] = to_datetime(to_datetime(prices["Date"], unit="s").dt.date)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Date'
# 127.0.0.1 - - [25/Feb/2021 19:48:47] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 165, in _read_one_data
#     prices["Date"] = to_datetime(to_datetime(prices["Date"], unit="s").dt.date)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Date'
# 127.0.0.1 - - [25/Feb/2021 19:48:47] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 153, in _read_one_data
#     resp = self._get_response(url, params=params)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 181, in _get_response
#     raise RemoteDataError(msg)
# pandas_datareader._utils.RemoteDataError: Unable to read URL: https://finance.yahoo.com/quote//history?period1=1420113600&period2=1614340799&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420113600%26period2%3d1614340799%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420113600%26period2%3d1614340799%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# 127.0.0.1 - - [25/Feb/2021 19:48:50] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol do using YahooDailyReader
# 127.0.0.1 - - [25/Feb/2021 19:49:07] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Feb/2021 19:49:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Feb/2021 19:49:08] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 157, in _read_one_data
#     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 160, in _read_one_data
#     raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
# pandas_datareader._utils.RemoteDataError: No data fetched for symbol do using YahooDailyReader
# 127.0.0.1 - - [25/Feb/2021 19:49:12] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Feb/2021 19:49:12] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-a4fd982921f0>", line 18, in update_graph
#     df = web.DataReader(input_data, 'yahoo', start, end)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py", line 199, in wrapper
#     return func(*args, **kwargs)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/data.py", line 376, in DataReader
#     return YahooDailyReader(
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 253, in read
#     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py", line 153, in _read_one_data
#     resp = self._get_response(url, params=params)
#   File "/home/sbhushans/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py", line 181, in _get_response
#     raise RemoteDataError(msg)
# pandas_datareader._utils.RemoteDataError: Unable to read URL: https://finance.yahoo.com/quote//history?period1=1420113600&period2=1614340799&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420113600%26period2%3d1614340799%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2f%2fhistory%3fperiod1%3d1420113600%26period2%3d1614340799%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# 127.0.0.1 - - [25/Feb/2021 19:49:14] "POST /_dash-update-component HTTP/1.1" 500 -
